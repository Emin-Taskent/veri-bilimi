# %% [markdown]
# # Matris Çarpanlarına Ayırma ( Matrix Factorization )

# %%
# Matrix factorization bir tablodaki boşlukların bir modele uygun biçimde doldurulmasıdır.

# Örneğin bu serimizin bir önceki bölümünde user-based collaborative filtering ile tavsiyelerde bulunmuştuk;
# Bu tavsiyeleri filmler ve bu filmlere verilen ratingler üzerinden yapmıştık.
# Hatırlamak amacıyla ilgili tablomuzu çağıralım.

import pandas as pd

user_movie_pivot = pd.read_csv('datasets/user_movie_pivot.csv')
user_movie_pivot
# Out:
#         'burbs, The (1989)  (500) Days of Summer (2009)  \
# 0                      NaN                          NaN
# 1                      NaN                          NaN
# 2                      NaN                          NaN
# 3                      NaN                          NaN
# 4                      NaN                          NaN
# ...                    ...                          ...
# 138488                 NaN                          NaN
# 138489                 NaN                          NaN
# 138490                 NaN                          NaN
# 138491                 NaN                          NaN
# 138492                 NaN                          NaN
#
#         *batteries not included (1987)  ...And Justice for All (1979)  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
# ...                                ...                            ...
# 138488                             NaN                            NaN
# 138489                             NaN                            NaN
# 138490                             NaN                            NaN
# 138491                             NaN                            NaN
# 138492                             NaN                            NaN
#
#         10 Things I Hate About You (1999)  10,000 BC (2008)  \
# 0                                     NaN               NaN
# 1                                     NaN               NaN
# 2                                     NaN               NaN
# 3                                     NaN               NaN
# 4                                     NaN               NaN
# ...                                   ...               ...
# 138488                                NaN               NaN
# 138489                                NaN               NaN
# 138490                                NaN               NaN
# 138491                                NaN               NaN
# 138492                                NaN               NaN
#
#         101 Dalmatians (1996)  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 138488                    NaN
# 138489                    NaN
# 138490                    NaN
# 138491                    NaN
# 138492                    3.0
#
#         101 Dalmatians (One Hundred and One Dalmatians) (1961)  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 138488                                                NaN
# 138489                                                NaN
# 138490                                                2.5
# 138491                                                NaN
# 138492                                                3.5
#
#         102 Dalmatians (2000)  12 Angry Men (1957)  ...  \
# 0                         NaN                  NaN  ...
# 1                         NaN                  NaN  ...
# 2                         NaN                  NaN  ...
# 3                         NaN                  NaN  ...
# 4                         NaN                  NaN  ...
# ...                       ...                  ...  ...
# 138488                    NaN                  4.5  ...
# 138489                    NaN                  NaN  ...
# 138490                    NaN                  NaN  ...
# 138491                    NaN                  NaN  ...
# 138492                    NaN                  4.0  ...
#
#         Zero Dark Thirty (2012)  Zero Effect (1998)  Zodiac (2007)  \
# 0                           NaN                 NaN            NaN
# 1                           NaN                 NaN            NaN
# 2                           NaN                 NaN            NaN
# 3                           NaN                 NaN            NaN
# 4                           NaN                 NaN            NaN
# ...                         ...                 ...            ...
# 138488                      NaN                 NaN            NaN
# 138489                      NaN                 NaN            NaN
# 138490                      NaN                 NaN            NaN
# 138491                      NaN                 NaN            NaN
# 138492                      NaN                 NaN            NaN
#
#         Zombieland (2009)  Zoolander (2001)  Zulu (1964)  [REC] (2007)  \
# 0                     NaN               NaN          NaN           NaN
# 1                     NaN               NaN          NaN           NaN
# 2                     NaN               NaN          NaN           NaN
# 3                     NaN               NaN          NaN           NaN
# 4                     NaN               NaN          NaN           NaN
# ...                   ...               ...          ...           ...
# 138488                NaN               NaN          NaN           NaN
# 138489                NaN               NaN          NaN           NaN
# 138490                NaN               NaN          NaN           NaN
# 138491                NaN               NaN          NaN           NaN
# 138492                NaN               NaN          NaN           NaN
#
#         eXistenZ (1999)  xXx (2002)  ¡Three Amigos! (1986)
# 0                   NaN         NaN                    NaN
# 1                   NaN         NaN                    NaN
# 2                   NaN         NaN                    NaN
# 3                   NaN         NaN                    NaN
# 4                   NaN         NaN                    NaN
# ...                 ...         ...                    ...
# 138488              NaN         NaN                    NaN
# 138489              NaN         NaN                    NaN
# 138490              NaN         NaN                    NaN
# 138491              NaN         NaN                    NaN
# 138492              NaN         NaN                    NaN
#
# [138493 rows x 3159 columns]

# %% [markdown]
# Yukarıda görüldüğü üzere tablo üzerinde birçok kullanıcı bir çok filme oy vermemiştir. Dolayısıyla tabloda boş değerler vardır. Boşlukları doldurmak için user'lar ve movie'ler için var olduğu varsayılan Latent Feature'ların (gizli özelliklerin) ağırlıkları var olan veri üzerinden bulunur ve bu ağırlıklar ile var olmayan gözlemler için tahmin yapılır.
#
# Elimizde yukarıdaki gibi bir user-item matrix'i bulunmaktadır.
# - User-Item matrix'ini 2 tane daha az boyutlu matrix'e ayrıştıracağız.
# - 2 matrix'ten User-Item matrisine gidişin latenet factör'ler (gizli özelliklerle) ile gerçekleştiği varsayımında bulunacağız.
# - Dolu olan gözlemler üzerinden latent factor'lerin ağırlıklarını bulacağız.
# - Bulunan ağırlıklar ile boş olan gözlemleri dolduracağız.

# %%
    #                  Movies (n)
    #              ___________________                             ___         ____________________
    #             |                   |                           |   |    x  |  Movie Factors (q) | k  x n
    #             |                   |                           |   |        ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
    #             |                   |                           |   |            r: rating
    # Users (m)   |    Ratings (r)    |      ≈    User Factors (p)|   |            p: usesr factors
    #             |                   |                           |   |            q: movie factors
    #             |                   |                           |   |
    #             |___________________|                           |___| m x k

# %% [markdown]
# Biraz daha açıklayıcı olmak gerekirse, elimizde bir tablo var. Bu tablo kullanıcıların spesifik bir filme verdikleri puanları gösteriyor ve bir kullanıcı her filme doğal olarak puan veremez.
#
# Bir kullanıcının bir filmde sevdiği özellikler veya sevmediği özellikler olabilir. Mesela kullanıcı filmin aksiyon filmi olmasını sevebilir veya korku filmi olmasını sevmeyebilir. Başka bir örnek ise kullanıcı için bir filmde Brad Pitt'in olması kullanıcı açısından o filmi  ÇOK sevilebilir kılarken, Brad Pitt'in olmaması o kullanıcı için filmi AZ sevilebilir kılabilir. Biz buna User Factors diyeceğiz. Bunları direk olarak bilemediğimiz için bunlar aynı zamanda latent feature'dır.
#
# Aynı zamanda bir filmin kendine has özellikleri de filmin sevilebilirliğini etkileyebilir. Yani filmin bütçesinin yüksek olması daha kaliteli oyuncuların oynaması daha iyi görsel efektler bir filmi sevilebilir kılarken, bunların olmaması filmin daha kalitesiz olacağı genel geçer kanısı ile bilmi daha az sevilebilir kılabilir. Bir başka örnek olarak ise filmin yönetmeni verilebilir. Bir filmin yönetmeninin bakış açısı filmin sevilebilirliğini etkileyebilir. Biz bunlara da Movie Factors diyeceğiz. Bunları da direk olarak bilemediğimiz için bunlar aynı zamanda latent feature'dır.

# %%
# Konuya bir de şu şekilde yaklaşacağız,

# yukarıdaki User Factors matrisinin alt kısmına baktığımızda m x k ifadesini görüyoruz,
# m tane user var, k tane factor var diyebiliriz.

# yukarıdaki Movie Factors matrisinin alt kısmına baktığımızda k x n ifadesini görüyoruz,
# n tane film var, k tane factor var diyebiliriz.

# %%
# Ayrıca şöyle de diyebiliriz, bir kullanıcı bir filmi seviyorsa o kullanıcının filmi sevmesi için bazı faktörler vardır.
# Bu sebepler şu anda ölçülebilir değildir, lakin kullanıcının vermiş olduğuğ puanı oluşturan gizli faktörlerdir diyebiliriz.

# Az önceki faktörlerin filmlerde de karşılığı vardır. Filmlerin içerisinde de filmin beğenilmesini sağlayan faktörler vardır.

# %% [markdown]
# - Rating matrisinin iki factor matrisinin (dot product) ile oluştuğu varsayılır.
#
# - Factor matrisleri ise user latent factors ve movie latent factors olarak ikiye ayırabiliriz.
#
# - Latent factors karşımıza; latent features, gizli faktörler veya gizli değişkenler olarak gelebilir.
#
# - Kullanıcıların ve filmlerin latent feature'lar için skorlara sahip olduğu düşünülür.
#
# - Bu ağırlıklar (skorlar) önce var olan veri üzerinden bulunut ve sonra BLANK bölümler bu ağırlıklara göre doldurulur.

# %%
# Bu faktörler filmler için; komedi, korku, macera vs. olup olmaması,
#                            veya belirli bir oyuncunun, yönetmenin vs olup olmaması olabilir.

# Bu movie faktörlerinin kullanıcıdaki karşılıkları da user factors olacaktır.

# %% [markdown]
# <p align="center" >
#     <img src = "grafikler/matrixfactorization.png" />
# </p>

# %%
# U1 kullanıcının, M1 filmine verdiği rating'i r11 diye isimlendirelim;

# Teoriye göre;

# r11 = p11 x q11 + p12 x q21 eşitliği ile belirlenir. 

# Aynı şekilde r21 ise;

# r21 = p21 x q11 + p22 x q21  eşitliği ile belirlenir.

# %% [markdown]
# Şimdi buraya kadar işlemimizin teorisini anlatmaya çalıştık.
#
# Buradan sonra ise;
#
# - var olan değerler üzerinden iteratif bir şekilde tüm p ve q'lar bulunur ve sonra kullanılır.
#
#                 Burada bizi bir sorun beklemektedir. p ve q'lar nasıl bulunacaktır.
# - Başlangıçta rasgele p ve q değerleri iler rating matrisindeki değerler tahmin edilmeye çalışılır. Sonrasında aradaki farkın karelerinin en küçük olacak şekilde optimize edilmeye çalışılır.

# %%
# Yukarıda p ve q değerlerine rasgele değer vereceğimizi daha sonrasında ise bu değerler ile boş ratingleri tahmin edeceğimizi ifade etmiştik.
# Bu tahminler ile gerçek değerler arasındaki farkın kareleri toplamı ise "Mean Square Error" ile ifade edilir.
# Negatif değerler ile pozitif değerlerin birbirini götürmemesi için farkların kareleri alınmaktadır.
# Kare işlemi olduğu için daha sonra MSE'nin karekökü alınarak "Root Mean Square Error" hesaplanabilir.

# Bizler MSE'nin veya RMSE'nin minimum olmasını isteriz.
# Bunun için ise p ve q'nun en optimize değerler olması gerekir ki RMSE en küçük olsun.

# %%
# Burada yöntem olarak Gradient Descent kullanacağız.
# Gradient Descent fonksiyon minimizasyonu için kullanılan bir optimizasyon yöntemidir.

# %% [markdown]
# Gradient Descent ile
#
# Gradyanın negatidi olarak tanımlanan "en dik iniş" yönünde iterarif olarak parametre değerini güncelleyerek ilgili fonksiyonun minimum değerini vereek parametreleri buluruz.

# %%
# Yukarıdaki cümle bir hayli karmaşık gibi gözükmektedir ve bunu parça parça ele almak zorundayız.

# Lakin şunu ifade etmemiz gerekmektedir, diyelim ki bizim bir rating'imiz 5 olsun ve biz bu rating için 1 değerinde bir tahminde bulunalım.
# Şimdi bizim tahminimizin hatalı olduğu açıkça gözükmektedir, çünkü (5-1)^2 = 16'dır. Bizim bu hatayı azalmamız gerekmektedir.
# Bir sonraki tahmin değerimiz olarak rating'imiz 2 olsun. (5-2)^2 = 9'dur. Hatamızı azalttık.
# Bu işlemi MSE'miz minimum olana kadar bütün user'lar ve movie'ler için yapacağız.


# Yani "Gradient Descent" ile türeve dayalı olarak ağırlık matrisindeki p ve q işlemlerini iteratif olarak değiştireceğiz.

# Şimdi yukarıdaki tanımımızdan hareket edersek;

# Gradyan eğim ve türev demektir. Zaten hatırlarsak bir fonksiyonun belirli bir noktadaki türevi o noktadaki eğimini bize verirdi.
# Dolayısıyla bir fonksiyonun belirli bir noktadaki türevi, o noktadaki maksimum artış hızını verir.

# Dolayısıyla gradyanının (eğiminin veya türevinin) negatifine doğru gittiğimizde ve bu yöne iteratif olarak (her bir kullanıcı ve film için)
# ilgili fonksiyonu minimumlaştıracak şekilde parametreler bulunur.

# %%
# Artık kütüphanelerimizi iport edip sonrasında verilerimizi işleme vakti geldi :)

import pandas as pd
from surprise import Reader, SVD, Dataset, accuracy
from surprise.model_selection import GridSearchCV, train_test_split, cross_validate

# %%
# Adım 1: Veri Setinin Hazırlanması
# Adım 2: Modelleme
# Adım 3: Model Tuning
# Adım 4: Final Model ve Tahmin

# %% [markdown]
# ### Adım 1: Veri Setinin Hazırlanması

# %%
# Burada bütün veri seti üzerinden değil bir kaç film seçerek bu uygulamayı yürütüyor olacağız.

movie = pd.read_csv('datasets/movie_lens_dataset/movie.csv')
rating = pd.read_csv('datasets/movie_lens_dataset/rating.csv')
df = movie.merge(rating, how="left", on="movieId")
df.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating            timestamp
# 0     3.0     4.0  1999-12-11 13:36:47
# 1     6.0     5.0  1997-03-13 17:50:52
# 2     8.0     4.0  1996-06-05 13:37:51
# 3    10.0     4.0  1999-11-25 02:44:47
# 4    11.0     4.5  2009-01-02 01:13:41

# %%
# Takip edilebilirlik açısından 4 film seçeceğiz.

movie_ids = [130219, 356, 4422, 541]
movies = ["The Dark Knight (2011)",
          "Cries and Whispers (Viskningar och rop) (1972)",
          "Forrest Gump (1994)",
          "Blade Runner (1982)"]

# %%
sample_df = df[df.movieId.isin(movie_ids)]
sample_df.head()
# Out:
#          movieId                title                    genres  userId  \
# 2457839      356  Forrest Gump (1994)  Comedy|Drama|Romance|War     4.0
# 2457840      356  Forrest Gump (1994)  Comedy|Drama|Romance|War     7.0
# 2457841      356  Forrest Gump (1994)  Comedy|Drama|Romance|War     8.0
# 2457842      356  Forrest Gump (1994)  Comedy|Drama|Romance|War     9.0
# 2457843      356  Forrest Gump (1994)  Comedy|Drama|Romance|War    10.0
#
#          rating            timestamp
# 2457839     4.0  1996-08-24 09:28:42
# 2457840     4.0  2002-01-16 19:02:55
# 2457841     5.0  1996-06-05 13:44:19
# 2457842     4.0  2001-07-01 20:26:38
# 2457843     3.0  1999-11-25 02:32:02

# %%
sample_df.shape

# Seçtiğimiz 4 adet film için 97343 puan bulunmaktadır.
# Out:
# (97343, 6)

# %%
# Şimdi satırlara kullanıcıları, sütunlara fimleri ve tablonun içerisine de kullanıcıların filmlere verdikleri puanları
# görebileceğimiz bir pivot tablosunu oluşturacağız.

user_movie_df = sample_df.pivot_table(index=["userId"],
                                      columns=["title"],
                                      values="rating")

user_movie_df
# Out:
# title     Blade Runner (1982)  Cries and Whispers (Viskningar och rop) (1972)  \
# userId
# 1.0                       4.0                                             NaN
# 2.0                       5.0                                             NaN
# 3.0                       5.0                                             NaN
# 4.0                       NaN                                             NaN
# 7.0                       NaN                                             NaN
# ...                       ...                                             ...
# 138474.0                  NaN                                             NaN
# 138483.0                  4.0                                             NaN
# 138484.0                  NaN                                             NaN
# 138486.0                  NaN                                             NaN
# 138493.0                  NaN                                             NaN
#
# title     Forrest Gump (1994)  The Dark Knight (2011)
# userId
# 1.0                       NaN                     NaN
# 2.0                       NaN                     NaN
# 3.0                       NaN                     NaN
# 4.0                       4.0                     NaN
# 7.0                       4.0                     NaN
# ...                       ...                     ...
# 138474.0                  5.0                     NaN
# 138483.0                  4.0                     NaN
# 138484.0                  5.0                     NaN
# 138486.0                  5.0                     NaN
# 138493.0                  5.0                     NaN
#
# [76918 rows x 4 columns]

# %%
user_movie_df.shape

# 76918 satır kullanıcıları ifade etmektedir.
# Out:
# (76918, 4)

# %%
# Reader fonksiyonunu suprise kütüphanesi ile import etmiştik.
# Reader fonksiyonu ile biz skalamızı ifade ediyoruz.

reader = Reader(rating_scale=(1, 5))

# %%
# Yine suprise kütüphanesi bizden veriyi belirli bir formatta ister 
# ve bunun için de "Dataset" fonksiyonu ve ".load_from_df()" metodunu kullanırız.
# ".load_from_df()" metodunun içerisine ise satır, sütun, kesişim ve skala bilgilerini göndeririz.

# Kendi documentation'ına da göz atmanın faydalı olduğunu düşünüyorum.
# The dataframe containing the ratings. 
# It must have three columns, corresponding to the user (raw) ids, the item (raw) ids, and the ratings, in this order.

data = Dataset.load_from_df(sample_df[['userId',
                                       'movieId',
                                       'rating']], reader)

# Yukarıdaki kodu çalıştırarak verimizi surprise kütüphanesinin istediği formaya getirmiş olduk.

# %% [markdown]
# ### Adım 2: Modelleme

# %%
# Makine öğrenmesine daha giriş yapmadık lakin; bu şekildeki öğrenmelerde (makine öğrenmesi veya istatistiksel öğrenme vs. de olabilir)
# Veri setimizi train ve test olmak üzere ikiye böleriz.

# Bu şekilde modelizimi train'de geliştirir ve verinin test kısmında ise geliştirdiğimiz modeli deneriz (test ederiz).

# Bu şekilde verimizin öğrendiği veride gözden kaçırdığımız bir şeyden dolayı çok iyi sonuç verip, 
# diğer verilerde hatalı sonuçlar vermesinin önüne geçmeye çalışırız.

# %%
# Veriyi bulmak için scikit-learn değil, suprise içerisindeki "train_test_split" fonksiyonunu çağıracağız.

trainset, testset = train_test_split(data, test_size=.25)

# %%
# Bir sonraki aşamada ise model nesnemizi oluşturacağız.

svd_model = SVD()

# Peki nedir bu model nesnesi, matrix factorization yöntemini kullanacak olduğumuz fonksiyon olacaktır.

# %%
# Bir önceki kısımda nesnemizi oluşturduk ve bu nesnemizi kullanacarak, 
# train dataset (trainset) ile beraber bir model kurma (fit etme) işlemi yapacağız.

svd_model.fit(trainset)

# %%
# Modelimizi fit ettik ve şimdi test dataseti (testset) üzerinde bir test edelim;

predictions = svd_model.test(testset)
predictions
# Out:
# [Prediction(uid=127014.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=110990.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=36440.0, iid=541, r_ui=5.0, est=4.056819754437834, details={'was_impossible': False}),
#  Prediction(uid=18119.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=38006.0, iid=541, r_ui=3.5, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=102216.0, iid=356, r_ui=0.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=77932.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=16424.0, iid=541, r_ui=4.0, est=4.048103753615669, details={'was_impossible': False}),
#  Prediction(uid=104816.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=81254.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=92821.0, iid=356, r_ui=4.0, est=3.803636159729814, details={'was_impossible': False}),
#  Prediction(uid=89113.0, iid=356, r_ui=1.5, est=4.105677563972792, details={'was_impossible': False}),
#  Prediction(uid=33587.0, iid=541, r_ui=5.0, est=4.05448530690765, details={'was_impossible': False}),
#  Prediction(uid=17486.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=79180.0, iid=356, r_ui=2.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=81198.0, iid=356, r_ui=4.0, est=3.797261919656513, details={'was_impossible': False}),
#  Prediction(uid=76738.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=14148.0, iid=356, r_ui=4.0, est=4.214181984770396, details={'was_impossible': False}),
#  Prediction(uid=86957.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=43866.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=95693.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=59180.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=13318.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=39039.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=40040.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=38970.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=68374.0, iid=356, r_ui=3.0, est=4.080959815127408, details={'was_impossible': False}),
#  Prediction(uid=86847.0, iid=541, r_ui=5.0, est=3.922404700643964, details={'was_impossible': False}),
#  Prediction(uid=16980.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=81254.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=717.0, iid=356, r_ui=3.5, est=4.178197035732601, details={'was_impossible': False}),
#  Prediction(uid=28657.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=116031.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=1649.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=56485.0, iid=541, r_ui=2.5, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=80206.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=5005.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=8208.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=73603.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=81101.0, iid=541, r_ui=2.5, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=130465.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=22023.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=84133.0, iid=356, r_ui=2.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=128103.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=70666.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=55528.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=20593.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=15876.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=95336.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=91274.0, iid=541, r_ui=4.5, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=66716.0, iid=356, r_ui=4.0, est=3.908255721309756, details={'was_impossible': False}),
#  Prediction(uid=125497.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=81813.0, iid=356, r_ui=2.5, est=3.9782137815126397, details={'was_impossible': False}),
#  Prediction(uid=6624.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=9677.0, iid=356, r_ui=4.5, est=3.8554816613090885, details={'was_impossible': False}),
#  Prediction(uid=26840.0, iid=356, r_ui=4.5, est=3.9549292547832957, details={'was_impossible': False}),
#  Prediction(uid=134612.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=49483.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=14092.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=84028.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=11165.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=134182.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=63702.0, iid=356, r_ui=5.0, est=3.860651820682796, details={'was_impossible': False}),
#  Prediction(uid=107317.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=38957.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=47232.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=115972.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=91343.0, iid=356, r_ui=4.0, est=4.180189375158442, details={'was_impossible': False}),
#  Prediction(uid=7943.0, iid=541, r_ui=3.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=44356.0, iid=356, r_ui=4.0, est=4.102608694192907, details={'was_impossible': False}),
#  Prediction(uid=71443.0, iid=541, r_ui=5.0, est=4.1596445859709785, details={'was_impossible': False}),
#  Prediction(uid=48712.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=62046.0, iid=356, r_ui=4.5, est=4.073805784163131, details={'was_impossible': False}),
#  Prediction(uid=118742.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=66650.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=9329.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=108876.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=35709.0, iid=541, r_ui=3.5, est=4.386788793610814, details={'was_impossible': False}),
#  Prediction(uid=34238.0, iid=356, r_ui=4.0, est=4.008066174569119, details={'was_impossible': False}),
#  Prediction(uid=132605.0, iid=541, r_ui=3.0, est=4.201682689839853, details={'was_impossible': False}),
#  Prediction(uid=33063.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=93963.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=367.0, iid=356, r_ui=4.0, est=4.158943414690796, details={'was_impossible': False}),
#  Prediction(uid=71745.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=105752.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=43260.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=63644.0, iid=356, r_ui=1.0, est=3.962535803876489, details={'was_impossible': False}),
#  Prediction(uid=29161.0, iid=541, r_ui=4.5, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=95474.0, iid=541, r_ui=4.5, est=4.193534717352631, details={'was_impossible': False}),
#  Prediction(uid=17884.0, iid=356, r_ui=2.0, est=4.095111693699617, details={'was_impossible': False}),
#  Prediction(uid=85532.0, iid=541, r_ui=5.0, est=4.0751814945787235, details={'was_impossible': False}),
#  Prediction(uid=32101.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=57450.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=31390.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=104303.0, iid=541, r_ui=4.0, est=4.18719589680344, details={'was_impossible': False}),
#  Prediction(uid=123576.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=92799.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=41533.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=134485.0, iid=356, r_ui=2.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=98753.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=88719.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=69127.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=111124.0, iid=356, r_ui=1.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=27937.0, iid=356, r_ui=2.0, est=3.937528459682563, details={'was_impossible': False}),
#  Prediction(uid=70935.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=846.0, iid=541, r_ui=5.0, est=4.098232892043876, details={'was_impossible': False}),
#  Prediction(uid=35942.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=128203.0, iid=541, r_ui=5.0, est=4.22303677243916, details={'was_impossible': False}),
#  Prediction(uid=101062.0, iid=356, r_ui=3.5, est=4.084664728725254, details={'was_impossible': False}),
#  Prediction(uid=65876.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=1682.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=102834.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=40031.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=67013.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=68472.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=78567.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=68871.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=43233.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=108377.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=134728.0, iid=541, r_ui=4.5, est=4.04697980857912, details={'was_impossible': False}),
#  Prediction(uid=48829.0, iid=356, r_ui=1.0, est=3.734545796092436, details={'was_impossible': False}),
#  Prediction(uid=3743.0, iid=356, r_ui=5.0, est=4.179732019488272, details={'was_impossible': False}),
#  Prediction(uid=81279.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=38130.0, iid=541, r_ui=3.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=34855.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=120150.0, iid=541, r_ui=4.5, est=4.144577605022665, details={'was_impossible': False}),
#  Prediction(uid=67563.0, iid=541, r_ui=4.0, est=4.152413254653459, details={'was_impossible': False}),
#  Prediction(uid=31219.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=89940.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=126462.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=107210.0, iid=356, r_ui=1.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=90618.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=81349.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=10401.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=31723.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=13315.0, iid=541, r_ui=4.0, est=4.219409242770922, details={'was_impossible': False}),
#  Prediction(uid=13022.0, iid=356, r_ui=2.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=99304.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=90129.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=119449.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=90807.0, iid=541, r_ui=4.0, est=4.146839657828667, details={'was_impossible': False}),
#  Prediction(uid=106576.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=37222.0, iid=356, r_ui=2.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=70731.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=248.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=51891.0, iid=541, r_ui=3.0, est=4.406196455343054, details={'was_impossible': False}),
#  Prediction(uid=33056.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=118464.0, iid=541, r_ui=2.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=21863.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=129205.0, iid=541, r_ui=3.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=13253.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=11329.0, iid=356, r_ui=5.0, est=4.097304469257597, details={'was_impossible': False}),
#  Prediction(uid=711.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=59896.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=745.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=17662.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=91106.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=24467.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=75898.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=21755.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=35437.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=52405.0, iid=541, r_ui=5.0, est=3.8514154243484384, details={'was_impossible': False}),
#  Prediction(uid=29810.0, iid=356, r_ui=3.0, est=3.97970846125889, details={'was_impossible': False}),
#  Prediction(uid=34632.0, iid=4422, r_ui=5.0, est=3.616190266118287, details={'was_impossible': False}),
#  Prediction(uid=18145.0, iid=356, r_ui=5.0, est=4.108623121020736, details={'was_impossible': False}),
#  Prediction(uid=38355.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=53298.0, iid=356, r_ui=4.0, est=3.8877058049913837, details={'was_impossible': False}),
#  Prediction(uid=85700.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=101628.0, iid=541, r_ui=5.0, est=4.030933109640225, details={'was_impossible': False}),
#  Prediction(uid=69749.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=47919.0, iid=356, r_ui=0.5, est=4.185820001485598, details={'was_impossible': False}),
#  Prediction(uid=137450.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=130781.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=59431.0, iid=541, r_ui=5.0, est=4.220270515161439, details={'was_impossible': False}),
#  Prediction(uid=89813.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=69807.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=22674.0, iid=541, r_ui=4.0, est=4.02513929898237, details={'was_impossible': False}),
#  Prediction(uid=115680.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=110846.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=90012.0, iid=541, r_ui=3.0, est=4.154016428373699, details={'was_impossible': False}),
#  Prediction(uid=114827.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=84377.0, iid=541, r_ui=4.0, est=4.216084959611513, details={'was_impossible': False}),
#  Prediction(uid=62863.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=123223.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=278.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=108734.0, iid=356, r_ui=3.5, est=3.7974687171633446, details={'was_impossible': False}),
#  Prediction(uid=97091.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=95984.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=102911.0, iid=356, r_ui=2.5, est=4.056869716122413, details={'was_impossible': False}),
#  Prediction(uid=58947.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=131442.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=125959.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=9426.0, iid=356, r_ui=3.0, est=4.274810999933187, details={'was_impossible': False}),
#  Prediction(uid=85126.0, iid=356, r_ui=4.0, est=4.148776441581279, details={'was_impossible': False}),
#  Prediction(uid=121787.0, iid=356, r_ui=3.5, est=3.740797952277765, details={'was_impossible': False}),
#  Prediction(uid=104298.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=3895.0, iid=541, r_ui=2.5, est=4.152777338793948, details={'was_impossible': False}),
#  Prediction(uid=104075.0, iid=356, r_ui=5.0, est=4.034161154686696, details={'was_impossible': False}),
#  Prediction(uid=86279.0, iid=356, r_ui=5.0, est=4.237164398239682, details={'was_impossible': False}),
#  Prediction(uid=13384.0, iid=541, r_ui=3.5, est=4.033512929372007, details={'was_impossible': False}),
#  Prediction(uid=15237.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=16260.0, iid=356, r_ui=4.5, est=4.247235425242417, details={'was_impossible': False}),
#  Prediction(uid=83775.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=125205.0, iid=541, r_ui=4.0, est=3.7505453651923064, details={'was_impossible': False}),
#  Prediction(uid=71082.0, iid=356, r_ui=4.0, est=4.035261586873141, details={'was_impossible': False}),
#  Prediction(uid=121440.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=58919.0, iid=541, r_ui=5.0, est=3.9544259231652923, details={'was_impossible': False}),
#  Prediction(uid=18194.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=99320.0, iid=541, r_ui=5.0, est=4.230047706718125, details={'was_impossible': False}),
#  Prediction(uid=42449.0, iid=356, r_ui=2.0, est=3.887966870699814, details={'was_impossible': False}),
#  Prediction(uid=699.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=132317.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=12398.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=57976.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=16779.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=127292.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=9945.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=115679.0, iid=356, r_ui=2.5, est=3.9804569537555254, details={'was_impossible': False}),
#  Prediction(uid=54710.0, iid=356, r_ui=4.0, est=4.20070718590266, details={'was_impossible': False}),
#  Prediction(uid=64707.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=88721.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=96912.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=55589.0, iid=356, r_ui=5.0, est=4.178979267787929, details={'was_impossible': False}),
#  Prediction(uid=23913.0, iid=356, r_ui=1.0, est=4.115372904906608, details={'was_impossible': False}),
#  Prediction(uid=130960.0, iid=356, r_ui=3.0, est=3.8463292997188576, details={'was_impossible': False}),
#  Prediction(uid=52611.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=13666.0, iid=356, r_ui=4.0, est=4.110255390790301, details={'was_impossible': False}),
#  Prediction(uid=137277.0, iid=541, r_ui=5.0, est=4.190448332553471, details={'was_impossible': False}),
#  Prediction(uid=4346.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=78128.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=120824.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=249.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=3746.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=132990.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=126258.0, iid=356, r_ui=4.5, est=4.096218547504797, details={'was_impossible': False}),
#  Prediction(uid=4631.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=66938.0, iid=356, r_ui=2.5, est=3.862802287341994, details={'was_impossible': False}),
#  Prediction(uid=4162.0, iid=356, r_ui=5.0, est=3.9839281376191344, details={'was_impossible': False}),
#  Prediction(uid=2982.0, iid=356, r_ui=4.0, est=4.058001266815643, details={'was_impossible': False}),
#  Prediction(uid=51023.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=127768.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=136877.0, iid=541, r_ui=4.0, est=4.442759675877009, details={'was_impossible': False}),
#  Prediction(uid=72345.0, iid=541, r_ui=5.0, est=3.9590778191338982, details={'was_impossible': False}),
#  Prediction(uid=133694.0, iid=356, r_ui=3.0, est=3.836086054449604, details={'was_impossible': False}),
#  Prediction(uid=87544.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=122738.0, iid=541, r_ui=4.0, est=4.145573896707808, details={'was_impossible': False}),
#  Prediction(uid=103016.0, iid=541, r_ui=5.0, est=4.223451378095995, details={'was_impossible': False}),
#  Prediction(uid=35049.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=116467.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=84569.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=60081.0, iid=541, r_ui=4.0, est=4.242186334047813, details={'was_impossible': False}),
#  Prediction(uid=133481.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=18327.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=53627.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=128382.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=12407.0, iid=541, r_ui=4.5, est=4.342211404670116, details={'was_impossible': False}),
#  Prediction(uid=116238.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=37565.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=6172.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=90291.0, iid=4422, r_ui=4.0, est=3.9422656641839566, details={'was_impossible': False}),
#  Prediction(uid=61742.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=57332.0, iid=356, r_ui=5.0, est=3.9775030398180773, details={'was_impossible': False}),
#  Prediction(uid=120421.0, iid=356, r_ui=2.5, est=4.175280972354491, details={'was_impossible': False}),
#  Prediction(uid=133249.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=79564.0, iid=356, r_ui=1.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=64558.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=77457.0, iid=356, r_ui=3.5, est=4.2860650816525885, details={'was_impossible': False}),
#  Prediction(uid=115750.0, iid=356, r_ui=4.0, est=4.120535470655114, details={'was_impossible': False}),
#  Prediction(uid=89392.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=97227.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=30808.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=95963.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=34898.0, iid=356, r_ui=5.0, est=4.232717060125547, details={'was_impossible': False}),
#  Prediction(uid=72504.0, iid=356, r_ui=4.5, est=3.991254172061391, details={'was_impossible': False}),
#  Prediction(uid=9579.0, iid=541, r_ui=4.5, est=4.109007243741471, details={'was_impossible': False}),
#  Prediction(uid=46167.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=118127.0, iid=541, r_ui=5.0, est=3.983709042799076, details={'was_impossible': False}),
#  Prediction(uid=64897.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=112639.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=111319.0, iid=356, r_ui=1.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=26988.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=39226.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=1417.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=90938.0, iid=356, r_ui=4.5, est=3.9810032903172656, details={'was_impossible': False}),
#  Prediction(uid=106379.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=35285.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=119081.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=9145.0, iid=541, r_ui=4.0, est=4.399919443864752, details={'was_impossible': False}),
#  Prediction(uid=87445.0, iid=541, r_ui=4.0, est=4.337368108003533, details={'was_impossible': False}),
#  Prediction(uid=77205.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=80650.0, iid=356, r_ui=4.0, est=3.847817898113114, details={'was_impossible': False}),
#  Prediction(uid=35553.0, iid=356, r_ui=3.5, est=4.121204843644912, details={'was_impossible': False}),
#  Prediction(uid=106866.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=92774.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=128917.0, iid=541, r_ui=5.0, est=4.135214496772183, details={'was_impossible': False}),
#  Prediction(uid=29568.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=82049.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=45633.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=20432.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=38542.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=129170.0, iid=356, r_ui=5.0, est=4.096221894388382, details={'was_impossible': False}),
#  Prediction(uid=11033.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=101832.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=50151.0, iid=356, r_ui=0.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=105470.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=59475.0, iid=541, r_ui=3.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=117726.0, iid=4422, r_ui=4.5, est=3.7626079162554453, details={'was_impossible': False}),
#  Prediction(uid=121255.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=3986.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=74322.0, iid=356, r_ui=3.5, est=4.174259760625775, details={'was_impossible': False}),
#  Prediction(uid=66354.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=51994.0, iid=541, r_ui=3.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=129781.0, iid=541, r_ui=5.0, est=4.627399676033759, details={'was_impossible': False}),
#  Prediction(uid=50174.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=94695.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=38539.0, iid=541, r_ui=3.5, est=4.362154503867362, details={'was_impossible': False}),
#  Prediction(uid=48016.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=98034.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=44207.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=63914.0, iid=356, r_ui=1.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=128488.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=100522.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=47032.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=62069.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=112460.0, iid=541, r_ui=3.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=29764.0, iid=356, r_ui=5.0, est=4.009556793796507, details={'was_impossible': False}),
#  Prediction(uid=36506.0, iid=356, r_ui=3.5, est=4.025689116240251, details={'was_impossible': False}),
#  Prediction(uid=48267.0, iid=541, r_ui=2.0, est=4.297917694361493, details={'was_impossible': False}),
#  Prediction(uid=10813.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=123334.0, iid=541, r_ui=3.5, est=4.121406973058468, details={'was_impossible': False}),
#  Prediction(uid=37650.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=1959.0, iid=356, r_ui=3.5, est=3.8460784628968963, details={'was_impossible': False}),
#  Prediction(uid=129495.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=99.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=54119.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=46729.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=99923.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=31351.0, iid=356, r_ui=3.0, est=3.8016499167133078, details={'was_impossible': False}),
#  Prediction(uid=101050.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=36097.0, iid=541, r_ui=2.5, est=4.2246623337311, details={'was_impossible': False}),
#  Prediction(uid=98219.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=14022.0, iid=541, r_ui=4.5, est=4.3238632781043815, details={'was_impossible': False}),
#  Prediction(uid=83356.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=58963.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=50408.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=52552.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=113940.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=113246.0, iid=541, r_ui=5.0, est=4.235041971091826, details={'was_impossible': False}),
#  Prediction(uid=121470.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=19500.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=14348.0, iid=356, r_ui=4.0, est=4.113474753659402, details={'was_impossible': False}),
#  Prediction(uid=103869.0, iid=541, r_ui=4.0, est=4.062659035731966, details={'was_impossible': False}),
#  Prediction(uid=34311.0, iid=356, r_ui=4.0, est=3.858246742547154, details={'was_impossible': False}),
#  Prediction(uid=115124.0, iid=541, r_ui=4.0, est=4.224608348885024, details={'was_impossible': False}),
#  Prediction(uid=100631.0, iid=356, r_ui=4.0, est=4.090638633151393, details={'was_impossible': False}),
#  Prediction(uid=83726.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=116623.0, iid=541, r_ui=4.0, est=4.361567997428608, details={'was_impossible': False}),
#  Prediction(uid=48960.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=109725.0, iid=356, r_ui=4.0, est=3.9897975518819186, details={'was_impossible': False}),
#  Prediction(uid=22972.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=105696.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=112885.0, iid=541, r_ui=3.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=26112.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=39773.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=27672.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=103694.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=111341.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=74613.0, iid=541, r_ui=4.5, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=39355.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=59398.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=87465.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=95581.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=49285.0, iid=356, r_ui=1.0, est=3.685624950348453, details={'was_impossible': False}),
#  Prediction(uid=8582.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=39749.0, iid=356, r_ui=5.0, est=4.118671469942717, details={'was_impossible': False}),
#  Prediction(uid=64091.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=96469.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=35337.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=65380.0, iid=356, r_ui=4.0, est=4.328169494394773, details={'was_impossible': False}),
#  Prediction(uid=99847.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=46041.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=46348.0, iid=541, r_ui=3.5, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=80612.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=104884.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=67852.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=133356.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=41536.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=116757.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=82241.0, iid=541, r_ui=4.0, est=4.278799633987217, details={'was_impossible': False}),
#  Prediction(uid=80847.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=111405.0, iid=356, r_ui=2.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=71564.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=92622.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=121319.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=134352.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=90191.0, iid=541, r_ui=4.5, est=4.221643105603562, details={'was_impossible': False}),
#  Prediction(uid=136061.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=100715.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=45224.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=81141.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=81687.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=55578.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=84431.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=26835.0, iid=541, r_ui=5.0, est=4.140958700623437, details={'was_impossible': False}),
#  Prediction(uid=27222.0, iid=356, r_ui=4.5, est=4.240611115188642, details={'was_impossible': False}),
#  Prediction(uid=103382.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=18467.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=118193.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=108819.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=104347.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=72920.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=51051.0, iid=541, r_ui=4.5, est=4.285869032472372, details={'was_impossible': False}),
#  Prediction(uid=36265.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=36751.0, iid=541, r_ui=4.5, est=3.9657387237342667, details={'was_impossible': False}),
#  Prediction(uid=71800.0, iid=356, r_ui=4.0, est=3.66199346421187, details={'was_impossible': False}),
#  Prediction(uid=136980.0, iid=356, r_ui=3.0, est=3.9438476056376066, details={'was_impossible': False}),
#  Prediction(uid=118582.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=29406.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=35650.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=101827.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=125328.0, iid=541, r_ui=5.0, est=4.1008882486274105, details={'was_impossible': False}),
#  Prediction(uid=35051.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=2875.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=40069.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=115614.0, iid=356, r_ui=5.0, est=4.120991497586131, details={'was_impossible': False}),
#  Prediction(uid=127410.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=27618.0, iid=356, r_ui=2.0, est=4.010204537699595, details={'was_impossible': False}),
#  Prediction(uid=11680.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=176.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=3057.0, iid=541, r_ui=4.0, est=4.275056549777995, details={'was_impossible': False}),
#  Prediction(uid=18875.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=105301.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=116111.0, iid=541, r_ui=3.0, est=4.235764727991699, details={'was_impossible': False}),
#  Prediction(uid=69980.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=59137.0, iid=541, r_ui=3.0, est=4.252233468269236, details={'was_impossible': False}),
#  Prediction(uid=31408.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=14953.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=110345.0, iid=541, r_ui=5.0, est=4.283071930440938, details={'was_impossible': False}),
#  Prediction(uid=126236.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=83807.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=114554.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=25068.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=73018.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=121930.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=29650.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=33520.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=49276.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=56672.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=110860.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=6162.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=117049.0, iid=356, r_ui=3.0, est=4.227923967999984, details={'was_impossible': False}),
#  Prediction(uid=99830.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=22388.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=75199.0, iid=356, r_ui=4.0, est=3.9421562331159445, details={'was_impossible': False}),
#  Prediction(uid=61703.0, iid=541, r_ui=3.0, est=4.54432212425363, details={'was_impossible': False}),
#  Prediction(uid=88209.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=76769.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=22060.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=23535.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=120425.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=55349.0, iid=356, r_ui=2.0, est=4.260763667684837, details={'was_impossible': False}),
#  Prediction(uid=111764.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=37264.0, iid=541, r_ui=4.0, est=4.1631678410731645, details={'was_impossible': False}),
# ...
#  Prediction(uid=10085.0, iid=356, r_ui=5.0, est=3.993087927438223, details={'was_impossible': False}),
#  Prediction(uid=95560.0, iid=356, r_ui=5.0, est=3.863717561019352, details={'was_impossible': False}),
#  Prediction(uid=100694.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=9266.0, iid=541, r_ui=5.0, est=4.234898427697925, details={'was_impossible': False}),
#  Prediction(uid=119466.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=133266.0, iid=541, r_ui=3.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=105494.0, iid=356, r_ui=5.0, est=4.154170408442011, details={'was_impossible': False}),
#  Prediction(uid=2393.0, iid=541, r_ui=5.0, est=4.276369718313214, details={'was_impossible': False}),
#  Prediction(uid=58333.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=112377.0, iid=356, r_ui=2.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=12239.0, iid=541, r_ui=3.5, est=4.224824810138504, details={'was_impossible': False}),
#  Prediction(uid=32158.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=125421.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=94320.0, iid=356, r_ui=4.0, est=4.2050387385912105, details={'was_impossible': False}),
#  Prediction(uid=104143.0, iid=541, r_ui=4.5, est=4.001689845723172, details={'was_impossible': False}),
#  Prediction(uid=86236.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=83571.0, iid=356, r_ui=4.0, est=3.9214853687675513, details={'was_impossible': False}),
#  Prediction(uid=59153.0, iid=356, r_ui=3.0, est=3.936172953622611, details={'was_impossible': False}),
#  Prediction(uid=2212.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=14745.0, iid=541, r_ui=4.5, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=68327.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=93421.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=42745.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=104669.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=86825.0, iid=356, r_ui=3.5, est=3.8662306812495544, details={'was_impossible': False}),
#  Prediction(uid=69392.0, iid=541, r_ui=4.0, est=3.945077084918325, details={'was_impossible': False}),
#  Prediction(uid=132973.0, iid=356, r_ui=4.5, est=4.050813322080929, details={'was_impossible': False}),
#  Prediction(uid=78991.0, iid=356, r_ui=5.0, est=3.8439035700460726, details={'was_impossible': False}),
#  Prediction(uid=33072.0, iid=541, r_ui=1.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=103195.0, iid=541, r_ui=4.5, est=4.223817333756779, details={'was_impossible': False}),
#  Prediction(uid=89891.0, iid=541, r_ui=3.5, est=4.196680516809393, details={'was_impossible': False}),
#  Prediction(uid=118516.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=5110.0, iid=541, r_ui=4.0, est=4.236402198986701, details={'was_impossible': False}),
#  Prediction(uid=119943.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=137272.0, iid=356, r_ui=2.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=39771.0, iid=541, r_ui=5.0, est=4.2532429510168726, details={'was_impossible': False}),
#  Prediction(uid=20579.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=96942.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=94346.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=72381.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=70929.0, iid=541, r_ui=4.0, est=4.511575702581637, details={'was_impossible': False}),
#  Prediction(uid=29646.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=97717.0, iid=541, r_ui=2.5, est=4.214316907247261, details={'was_impossible': False}),
#  Prediction(uid=122641.0, iid=541, r_ui=4.0, est=3.8828595529095713, details={'was_impossible': False}),
#  Prediction(uid=40944.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=125650.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=88129.0, iid=541, r_ui=4.0, est=3.9261074603021164, details={'was_impossible': False}),
#  Prediction(uid=81623.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=63954.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=33565.0, iid=541, r_ui=4.5, est=4.056331208391438, details={'was_impossible': False}),
#  Prediction(uid=35015.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=43878.0, iid=356, r_ui=2.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=129450.0, iid=541, r_ui=4.0, est=4.334528278385537, details={'was_impossible': False}),
#  Prediction(uid=138265.0, iid=356, r_ui=2.5, est=4.167629920343122, details={'was_impossible': False}),
#  Prediction(uid=105113.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=82571.0, iid=356, r_ui=3.0, est=3.823240003969599, details={'was_impossible': False}),
#  Prediction(uid=138431.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=114087.0, iid=356, r_ui=2.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=122310.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=19221.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=49420.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=104479.0, iid=356, r_ui=5.0, est=4.120532827361274, details={'was_impossible': False}),
#  Prediction(uid=123163.0, iid=4422, r_ui=5.0, est=4.009938655497138, details={'was_impossible': False}),
#  Prediction(uid=72679.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=122364.0, iid=541, r_ui=4.0, est=4.35767476587497, details={'was_impossible': False}),
#  Prediction(uid=54973.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=48124.0, iid=356, r_ui=5.0, est=4.5422226408353685, details={'was_impossible': False}),
#  Prediction(uid=43223.0, iid=356, r_ui=3.5, est=4.142283875880841, details={'was_impossible': False}),
#  Prediction(uid=123079.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=84628.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=123287.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=15029.0, iid=541, r_ui=4.0, est=4.00556835561169, details={'was_impossible': False}),
#  Prediction(uid=80621.0, iid=356, r_ui=2.0, est=3.9509457901413105, details={'was_impossible': False}),
#  Prediction(uid=128875.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=93122.0, iid=356, r_ui=5.0, est=4.0058270190372625, details={'was_impossible': False}),
#  Prediction(uid=117793.0, iid=356, r_ui=3.0, est=4.1373380953839325, details={'was_impossible': False}),
#  Prediction(uid=119295.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=41724.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=112645.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=99607.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=130073.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=83589.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=10276.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=94506.0, iid=541, r_ui=2.5, est=4.142725971378991, details={'was_impossible': False}),
#  Prediction(uid=68004.0, iid=356, r_ui=1.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=55466.0, iid=541, r_ui=4.5, est=4.122750593895669, details={'was_impossible': False}),
#  Prediction(uid=30166.0, iid=541, r_ui=3.0, est=4.246624099181994, details={'was_impossible': False}),
#  Prediction(uid=129311.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=21119.0, iid=541, r_ui=4.0, est=4.075992652303815, details={'was_impossible': False}),
#  Prediction(uid=157.0, iid=356, r_ui=5.0, est=4.106862770681874, details={'was_impossible': False}),
#  Prediction(uid=14845.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=4518.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=97512.0, iid=541, r_ui=4.0, est=4.260983504724854, details={'was_impossible': False}),
#  Prediction(uid=94905.0, iid=541, r_ui=3.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=31156.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=40610.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=53637.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=79901.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=76650.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=103772.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=64514.0, iid=541, r_ui=2.0, est=4.09882065779179, details={'was_impossible': False}),
#  Prediction(uid=116749.0, iid=541, r_ui=2.0, est=4.305704851785579, details={'was_impossible': False}),
#  Prediction(uid=57985.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=87857.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=26067.0, iid=541, r_ui=4.5, est=4.346318534174702, details={'was_impossible': False}),
#  Prediction(uid=66313.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=101873.0, iid=541, r_ui=4.0, est=4.172861708902777, details={'was_impossible': False}),
#  Prediction(uid=41727.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=1650.0, iid=356, r_ui=3.5, est=3.933119250548141, details={'was_impossible': False}),
#  Prediction(uid=104316.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=91487.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=11237.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=4200.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=96292.0, iid=541, r_ui=4.0, est=4.055328009343284, details={'was_impossible': False}),
#  Prediction(uid=40386.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=69137.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=60399.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=116866.0, iid=356, r_ui=3.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=110386.0, iid=356, r_ui=3.5, est=4.137616364195383, details={'was_impossible': False}),
#  Prediction(uid=46464.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=76273.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=75113.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=138234.0, iid=541, r_ui=5.0, est=4.320000893868658, details={'was_impossible': False}),
#  Prediction(uid=43402.0, iid=4422, r_ui=4.0, est=4.205819149367211, details={'was_impossible': False}),
#  Prediction(uid=1179.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=48097.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=71955.0, iid=541, r_ui=4.5, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=65.0, iid=356, r_ui=5.0, est=4.076447521402931, details={'was_impossible': False}),
#  Prediction(uid=74258.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=123601.0, iid=541, r_ui=5.0, est=3.8525793648730735, details={'was_impossible': False}),
#  Prediction(uid=11747.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=46068.0, iid=541, r_ui=2.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=82696.0, iid=541, r_ui=5.0, est=4.147257549925828, details={'was_impossible': False}),
#  Prediction(uid=118503.0, iid=541, r_ui=5.0, est=4.205905327257264, details={'was_impossible': False}),
#  Prediction(uid=88363.0, iid=541, r_ui=4.0, est=3.9243640845035124, details={'was_impossible': False}),
#  Prediction(uid=67017.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=1282.0, iid=356, r_ui=4.5, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=21012.0, iid=541, r_ui=5.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=41329.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=95287.0, iid=356, r_ui=3.5, est=3.9896709190881565, details={'was_impossible': False}),
#  Prediction(uid=131721.0, iid=356, r_ui=4.5, est=4.023082013602336, details={'was_impossible': False}),
#  Prediction(uid=94810.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=107628.0, iid=541, r_ui=4.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=73784.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=98498.0, iid=541, r_ui=3.0, est=4.18133124043154, details={'was_impossible': False}),
#  Prediction(uid=118095.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=120141.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=115623.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=20111.0, iid=356, r_ui=5.0, est=3.9384369445286147, details={'was_impossible': False}),
#  Prediction(uid=123398.0, iid=541, r_ui=4.5, est=4.144311232314579, details={'was_impossible': False}),
#  Prediction(uid=43065.0, iid=356, r_ui=4.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=55867.0, iid=356, r_ui=3.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=117323.0, iid=356, r_ui=5.0, est=4.0370562588277865, details={'was_impossible': False}),
#  Prediction(uid=73364.0, iid=356, r_ui=5.0, est=4.06528207864477, details={'was_impossible': False}),
#  ...]

# %%
# Şimdi çıktıyı bir yorumlamaya çalışalım;

# Prediction(uid=3685.0, iid=356, r_ui=4.5, est=4.090432247214464, details={'was_impossible': False})

# uid=3685.0 ID'li kullanıcının, id=356 ID'li filme verdiği
# r_ui=4.5 gerçek puan iken biz bu puanı est=4.090432247214464 olarak tahmin etmişiz.

# %% [markdown]
# Yukarıda görüldüğü üzere gerçek değerlerim ile tahmin değerlerim arasında farklılılar bulunmaktadır.
#
# Bizim bu farklılıkları görebilmemiz gerekir.

# %%
# Bu farklılılaı görebilmek için ise accuract nesnesini ve ".rmse()" metodunu kullanırız.

accuracy.rmse(predictions)

# Bu ne demektir;

# Bir kullanıcı için beklenen ortalama hatadır.
# Out:
# RMSE: 0.9326
# 0.9325846934203301

# %%
# Spesifik bir kullanıcı ve film için bir tahminde bulunmak istersek;

svd_model.predict(uid=1.0, iid=541, verbose=True)

# ID no'su 1 olan kullanıcının ID no'su 541 olan filme (ki film "Blade Runner (1982)") verdiği puanı tahmin etmeye çalışacağız.
# Out:
# user: 1.0        item: 541        r_ui = None   est = 4.18   {'was_impossible': False}
# Prediction(uid=1.0, iid=541, r_ui=None, est=4.18133124043154, details={'was_impossible': False})

# %%
# Bir de gerçek değerine bakalım;

sample_df[sample_df["userId"] == 1]

# Biz bu değeri 4.07 olarak tahmin ederken filme verilen gerçek puan ise 4'ttür.
# Modeli her eğittiğimizde bu değerler değişiklik gösterebilir.
# Zira modelin train ve test olarak nerelerden bölündüğünü tam olarak bilemiyoruz.
# Out:
#          movieId                title                  genres  userId  rating  \
# 3612352      541  Blade Runner (1982)  Action|Sci-Fi|Thriller     1.0     4.0
#
#                    timestamp
# 3612352  2005-04-02 23:30:03

# %% [markdown]
# ### Adım 3: Model Tuning (Model Kurma)

# %%
# Burada modelimizi optimize etmeye çalışacağız.
# Modeli optimize etmek modeli tahmin performansını arttırmaya çalışmak demektir.

# Bir modeli optimize etmeninin bir çok yolu olmasına rağmen;
# Biz burada modelin dışsal parametrelerini (yani kullanıcı tarafından ayarlanabilen veya hiper parametrelerini) "Nasıl optimize ederiz?"
# sorusuna cevap arıyor olacağız.

# Bizim burada müdahale edeceğimiz parametrelerden bir tanesi iteraasyon (tekrar) sayısıdır.
# Yukarıdaki tanımdan hatırlarsak p ve q parametrelerimizi iteratif olarak değiştiriyorduk.
# Yani biz kaç defa bu ağırlıkları güncelleyeceğiz.

# Bu parametrenin kullanıcı tarafından verilmesi veya optimize edilmesi gerekir.

# SVD() nesnesinin içerine bakıldığında, 
# içerisindeki parametrelerden bir tanesi
#   n_factors parametresi bulunmaktadır ve default'u son versiyonda 20 olarak gözükmektedir.
#   faktör sayısı arttılarak veya azaltılarak RMSE sayısı kontrol edilirse n_factors'ün arttırılıp azaltılmasına ilişkin yorum yapılabilir.
# SVD() içerisindeki bir başka parametre ise;
#   n_epochs parametresidir. Bu parametre ise iterasyon sayısını ifade eder. Ön tanımlı değeri ise 20'dir.

# Bunlara bizler daşsal olarak müdahale edebiliriz.

# %%
# Bu dışsal değerleri modelimize gönderebilmek için bir parametre ızgarası (parameter_grid) hazırlayacağız.

param_grid = {'n_epochs': [5, 10, 20],
              'lr_all': [0.002, 0.005, 0.007]}

# Yukarıdaki sözlükte ifade edilen şey; "n_epochs" değeri 5 iken VE "lr_all" değeri 0.02 iken modeli p ve q değerlerini hesapla diyoruz.

# %%
# Aşağıda ise verilen parametreleri farklı farklı çalıştıracak ve modeli arayacak bir fonksiyona ihtiyacımız olacak;

gs = GridSearchCV(SVD,
                  param_grid,
                  measures=['rmse', 'mae'],
                  cv=3,
                  n_jobs=-1,
                  joblib_verbose=True)

# Yukarıda "GridSearchCV()" fonksiyonunun içerisine;
# SVD nesnesini gönderiyoruz,
# parametre ızgarası gönderiyoruz,
# hatamızı hangi değerlere göre değerlendireceğimizi söylüyoruz (yukarıda RMSE ve MAE'a (mean absolute error) bakacağımızı ifade ettik),
# "cv=" parametresi ise bize çapraz sorgulama yapmak isteyip istemediğimizi sorar,
#   "cv=" parametresine girdiğimiz 3 değeri ise veri setini 3'e bölüp 2 set ile model kurup 1 set ile test edeceğini,
#   daha sonrasında diğer iki set ile model kurup farklı 1 parça ile test edeceğini
#   en sonunda ise kalan test edilen 2 parça ile modelin kurulup son parça ile modelin test edileceğini ifade eder.
#   En sonunda ise bu test işlemlerinin ortalamasını alır.
# "n_jobs=-1" işlemcileri full performans ile kullanması gerektiğini ifade eden parametredir.
# "joblib_verbose=True" ile de işlemler gerçekleşirken raporlama istediğimi ifade ediyorum.

# %%
gs.fit(data)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    6.4s finished

# %%
# Şimdi ise gs içerisindeki en iyi RMSE'ye sahip olan modelin RMSE'sini çağıralım,

gs.best_score['rmse']
# Out:
# 0.9305790433768855

# %%
# Bu sonucu veren en iyi parametreleri çağırmak istersek;

gs.best_params['rmse']
# Out:
# {'n_epochs': 10, 'lr_all': 0.002}

# %% [markdown]
# ### Adım 4: Final Model ve Tahmin

# %%
# SVD modelin çağırılabilecek metodlarına bir göz atalım.

dir(svd_model)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'bi',
#  'biased',
#  'bsl_options',
#  'bu',
#  'compute_baselines',
#  'compute_similarities',
#  'default_prediction',
#  'estimate',
#  'fit',
#  'get_neighbors',
#  'init_mean',
#  'init_std_dev',
#  'lr_bi',
#  'lr_bu',
#  'lr_pu',
#  'lr_qi',
#  'n_epochs',
#  'n_factors',
#  'predict',
#  'pu',
#  'qi',
#  'random_state',
#  'reg_bi',
#  'reg_bu',
#  'reg_pu',
#  'reg_qi',
#  'sgd',
#  'sim_options',
#  'test',
#  'trainset',
#  'verbose']

# %%
svd_model.n_epochs
# Out:
# 20

# %%
# Yukarıdaki modelimizde baktığımızda, en iyi sonucu veren parametrelerin, 
# SVD() fonksiyonundaki ön tanımlı değerlerinden farklı olabileceğini fark ettik.

# Bu sebeple bizim bu parametrelerle yeni bir model kurmamız gerekir.

svd_model = SVD(**gs.best_params['rmse'])

# Modelizimi yukarıdaki gibi kurabiliriz. 
# Dilersek kwargs (key-worded arguman) yerine elimizle teker teker {'n_epochs': 5, 'lr_all': 0.002} şeklinde de girebiliriz.

# %%
# Normalde biz verimizi train ve test diye ikiye bölmüştük,

# Biz yukarıda hiper parametrelerimizi optimize ettik ve hatalarımıza baktık, ne noktada olduğumuzu öğrendik,
# Bu sebeple modelleme işleminde verimizi train ve test diye ayırmamıza gerek kalmadan bütün veriyi gösterme yoluna gidebilirim.

data = data.build_full_trainset()

# %%
# Artık modelimizi fit etme vakti geldi :)

svd_model.fit(data)

# %%
# Bir de bir kıyaslama yapalım;

svd_model.predict(uid=1.0, iid=541, verbose=True)
# Out:
# user: 1.0        item: 541        r_ui = None   est = 4.24   {'was_impossible': False}
# Prediction(uid=1.0, iid=541, r_ui=None, est=4.237804199565605, details={'was_impossible': False})

# %%
sample_df[sample_df["userId"] == 1]
# Out:
#          movieId                title                  genres  userId  rating  \
# 3612352      541  Blade Runner (1982)  Action|Sci-Fi|Thriller     1.0     4.0
#
#                    timestamp
# 3612352  2005-04-02 23:30:03

# %%
# Modelimiz 4.0 olarak verilen rating'i 4.18 olarak tahmin etmiş.
